# %%
import cv2
import numpy as numpy
import matplotlib.pyplot as plt

# %%
org_img = cv2.imread(r"D:\\Coding\\ss_image_to_pencil\\images\\dog.jpg")

# %%
img_rgb = cv2.cvtColor(org_img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)
plt.show()
